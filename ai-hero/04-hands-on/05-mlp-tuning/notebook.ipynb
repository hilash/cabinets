# %% [markdown]
# # MLP tuning exercise
#
# **Your task:** beat Karpathy's val loss of 2.2 on the character MLP.
#
# Reuse your code from section 4.4. This notebook is for systematic experimentation — one function that takes hyperparameters and returns val loss.

# %%
import torch
import torch.nn.functional as F
import random

# %% [markdown]
# ## Data loading and build_dataset helper

# %%
# TODO: load words, build stoi/itos, split train/val/test
# TODO: build_dataset(words, block_size) -> (X, Y) where X is (N, block_size) and Y is (N,)

# %% [markdown]
# ## A single-function experiment runner

# %%
def run_experiment(block_size, emb_dim, hidden, lr_init, lr_late, steps, batch_size, seed=42):
    torch.manual_seed(seed)
    # TODO: build dataset at this block_size
    # TODO: init C, W1, b1, W2, b2
    # TODO: training loop with LR schedule (lr_init early, lr_late late)
    # TODO: return final_val_loss
    pass

# %% [markdown]
# ## Experiment grid

# %%
experiments = [
    # dict(block_size=3, emb_dim=10, hidden=200, lr_init=0.1, lr_late=0.01, steps=100000, batch_size=32),
    # dict(block_size=5, emb_dim=10, hidden=200, lr_init=0.1, lr_late=0.01, steps=100000, batch_size=32),
    # dict(block_size=5, emb_dim=20, hidden=300, lr_init=0.1, lr_late=0.01, steps=200000, batch_size=64),
    # etc.
]

# for i, cfg in enumerate(experiments):
#     loss = run_experiment(**cfg)
#     print(f'run {i+1}: val_loss={loss:.4f}  {cfg}')

# %% [markdown]
# Write your winning config into the index.md for this section.
